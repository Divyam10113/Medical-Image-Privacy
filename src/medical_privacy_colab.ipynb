# %% [markdown]
# # 🏥 Medical Image Privacy - Colab Training Notebook
#
# Welcome to the training lab! This notebook allows you to train the specific Diffusion Model we built locally on a powerful T4 GPU.

# %% [markdown]
# ## 1. Upload Project Files
# Upload the `project.zip` and `kaggle.json` file from your computer.

# %%
from google.colab import files
import os

# Upload 1: project.zip (The code we wrote)
print("⬆️ Please upload 'project.zip'...")
_ = files.upload()

# Upload 2: kaggle.json (For downloading the dataset)
print("⬆️ Please upload 'kaggle.json'...")
_ = files.upload()

# !unzip -o project.zip
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# ## 2. Install Dependencies
# We use the same `requirements.txt` to ensure consistency.

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## 3. Download Full Dataset (NIH Chest X-ray)
# This pulls the 2GB+ dataset directly to the Colab runtime.

# %%
# Download the sample dataset (2GB)
# !kaggle datasets download -d nih-chest-xrays/sample --unzip -p data/raw

# Verify download
import os
print(f"Found {len(os.listdir('data/raw'))} images!")

# %% [markdown]
# ## 4. Run Training 🚀
# We run the training script. We boost `epochs` to 50 for better results.

# %%
# !python src/train.py --epochs 50

# %% [markdown]
# ## 5. Download Model
# Save the trained weights back to your computer.

# %%
from google.colab import files
files.download('model.pth')
